# %% [markdown]
# # Ödev
#
# Ad: irfan eren
#
# Soyad: çiftçi
#
# Numara: G211210032

# %% [markdown]
# # Sütunların Açıklaması

# %% [markdown]
# Age: Age
#
# Race: other :American Indian/AK Native, Asian/Pacific Islander
#
# Marital Status: Marital Status
#
# T Stage: Adjusted AJCC 6th T
#
# N Stage: Adjusted AJCC 6th N
#
# 6th Stage: Breast Adjusted AJCC 6th Stage
#
# differentiate: the differentiation
#
# Grade: the grade
#
# A Stage: Regional — A neoplasm that has extended, Distant — A neoplasm that has spread to parts of the body remote from
#
# Tumor Size: Each indicates exact size in millimeters.
#
# Estrogen Status: Estrogen Status
#
# Progesterone Status: Progesterone Status
#
# Regional Node Examined: Regional Node Examined
#
# Reginol Node Positive: Reginol Node positive
#
# Surrvival months: Surrvival months
#
# Status: Dead or Alive

# %% [markdown]
# # Kütüphanelerin Yüklenmesi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

sns.set()
plt.style.use('ggplot')

# %% [markdown]
# gerekli olan kütüphanler yüklenir

# %%
df = pd.read_csv("/content/drive/MyDrive/Breast_Cancer.csv")
titles = ['Miss.', 'Mrs.']
first_names = ['Ayşe', 'Alice', 'Rebecca', 'Lea', 'Emily', 'Sarah', 'Lisa', 'Michelle', 'Jasmin', 'Abigail', 'Robin', 'Mary', 'Diana', 'Elizabeth', 'Kate', 'Isabel']
surnames = ['Smith', 'Brown', 'Wilson', 'Young', 'Stewart', 'Murray', 'Anderson', 'Walker', 'Reid', 'Clark', 'Scott', 'Miller']

full_names = [f"{np.random.choice(titles)} {np.random.choice(first_names)} {np.random.choice(surnames)}" for _ in range(len(df))]

df['Name']=full_names

# %% [markdown]
# burda daatset okunur ayrıca name adında yeni bir sütun eklenir ve random olarak atanır

# %%
df.head()
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
print(train_df)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 2665   61  White        Widowed       T1      N1       IIA
# 3740   52  White        Married       T2      N1       IIB
# 2138   50  White        Single        T1      N1       IIA
# 1419   66  White       Divorced       T1      N1       IIA
# 283    50  White      Separated       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 1130   63  White        Married       T1      N1       IIA
# 1294   46  White        Married       T1      N1       IIA
# 860    57  White        Single        T2      N1       IIB
# 3507   48  Other        Married       T2      N1       IIB
# 3174   53  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 2665  Moderately differentiated     2  Regional          14        Positive
# 3740        Well differentiated     1  Regional          34        Positive
# ...

# %% [markdown]
# train dataframe'i

# %%
print(test_df)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 1718   45  White        Married       T1      N1       IIA
# 1204   61  White        Married       T1      N1       IIA
# 2722   61  White        Married       T2      N2      IIIA
# 1937   40  White        Married       T3      N2      IIIA
# 1226   45  White        Married       T1      N1       IIA
# ...   ...    ...            ...      ...     ...       ...
# 1601   51  White        Married       T1      N2      IIIA
# 3471   57  White       Divorced       T2      N1       IIB
# 3463   52  White       Divorced       T2      N2      IIIA
# 3883   62  White        Married       T1      N1       IIA
# 2215   44  Other        Married       T1      N1       IIA
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 1718      Poorly differentiated     3  Regional          15        Positive
# 1204  Moderately differentiated     2  Regional          17        Positive
# ...

# %% [markdown]
# test dataframe'i

# %%
test_age=test_df["Age"]
print(test_age)
# Out:
# 1718    45
# 1204    61
# 2722    61
# 1937    40
# 1226    45
#         ..
# 1601    51
# 3471    57
# 3463    52
# 3883    62
# 2215    44
# Name: Age, Length: 805, dtype: int64

# %% [markdown]
# testteki yaşlar

# %%
train_age=train_df["Age"]
print(train_age)
# Out:
# 2665    61
# 3740    52
# 2138    50
# 1419    66
# 283     50
#         ..
# 1130    63
# 1294    46
# 860     57
# 3507    48
# 3174    53
# Name: Age, Length: 3219, dtype: int64

# %% [markdown]
# traindeki yaşlar

# %%
train_df.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status', 'Name'],
#       dtype='object')

# %%
train_df.dtypes
# Out:
# Age                        int64
# Race                      object
# Marital Status            object
# T Stage                   object
# N Stage                   object
# 6th Stage                 object
# differentiate             object
# Grade                     object
# A Stage                   object
# Tumor Size                 int64
# Estrogen Status           object
# Progesterone Status       object
# Regional Node Examined     int64
# Reginol Node Positive      int64
# Survival Months            int64
# Status                    object
# Name                      object
# dtype: object

# %% [markdown]
# Train dataframe'indeki sutünların veri tipleri

# %%
test_df.head()
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 1718   45  White        Married       T1      N1       IIA
# 1204   61  White        Married       T1      N1       IIA
# 2722   61  White        Married       T2      N2      IIIA
# 1937   40  White        Married       T3      N2      IIIA
# 1226   45  White        Married       T1      N1       IIA
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 1718      Poorly differentiated     3  Regional          15        Positive
# 1204  Moderately differentiated     2  Regional          17        Positive
# 2722  Moderately differentiated     2  Regional          28        Positive
# 1937  Moderately differentiated     2  Regional          60        Positive
# 1226        Well differentiated     1  Regional          14        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 1718            Positive                      24                      1
# ...

# %%
train_df.index
# Out:
# Index([2665, 3740, 2138, 1419,  283,  712,  274, 2288,  621, 1468,
#        ...
#        2169, 1638, 3092, 3772, 1095, 1130, 1294,  860, 3507, 3174],
#       dtype='int64', length=3219)

# %%
train_df.describe()
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  3219.000000  3219.000000             3219.000000
# mean     53.830071    30.333644               14.274309
# std       9.000450    20.753396                8.112302
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            3219.000000      3219.000000
# mean                4.223983        71.162162
# std                 5.187818        22.869855
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        89.000000
# max                46.000000       107.000000

# %% [markdown]
# Train dataframe' i hakkında genel bilgiler

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3219 entries, 2665 to 3174
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3219 non-null   int64
#  1   Race                    3219 non-null   object
#  2   Marital Status          3219 non-null   object
#  3   T Stage                 3219 non-null   object
#  4   N Stage                 3219 non-null   object
#  5   6th Stage               3219 non-null   object
#  6   differentiate           3219 non-null   object
#  7   Grade                   3219 non-null   object
#  8   A Stage                 3219 non-null   object
#  9   Tumor Size              3219 non-null   int64
#  10  Estrogen Status         3219 non-null   object
#  11  Progesterone Status     3219 non-null   object
#  12  Regional Node Examined  3219 non-null   int64
#  13  Reginol Node Positive   3219 non-null   int64
# ...

# %% [markdown]
# Train dataframe' i hakkında genel bilgiler

# %%
train_df["Tumor Size"].index
# Out:
# Index([2665, 3740, 2138, 1419,  283,  712,  274, 2288,  621, 1468,
#        ...
#        2169, 1638, 3092, 3772, 1095, 1130, 1294,  860, 3507, 3174],
#       dtype='int64', length=3219)

# %% [markdown]
# tumor size sütunundaki değerlerin indexleri

# %%
train_df["Tumor Size"].index.values
# Out:
# array([2665, 3740, 2138, ...,  860, 3507, 3174])

# %% [markdown]
# tumor size sütunundaki değerlerin index değerleri

# %%
plt.hist(train_df["Tumor Size"], bins=20, edgecolor='black')
plt.xlabel("Tumor Size")
plt.ylabel("Frequency")
plt.title("Distribution of Tumor Sizes")
plt.show()

# %% [markdown]
# tümor boyutları dağılımı

# %%
def bar_plot(variable):
    var=train_df[variable]
    varValue=var.value_counts()

    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
category1=["Race","Marital Status","Status","Survival Months","Tumor Size"]
for c in category1:
    bar_plot(c)
# Out:
# Race:
#  Race
# White    2709
# Other     271
# Black     239
# Name: count, dtype: int64
# Marital Status:
#  Marital Status
# Married      2103
# Single        519
# Divorced      376
# Widowed       188
# Separated      33
# Name: count, dtype: int64
# Status:
#  Status
# Alive    2723
# Dead      496
# Name: count, dtype: int64
# Survival Months:
#  Survival Months
# 69     70
# 98     60
# 63     58
# 102    57
# 81     57
#        ..
# 7       3
# 11      2
# 3       2
# 26      2
# 1       1
# Name: count, Length: 107, dtype: int64
# Tumor Size:
#  Tumor Size
# 25     216
# 15     211
# 30     185
# 20     176
# 18     134
#       ...
# 108      1
# 123      1
# 107      1
# 115      1
# 67       1
# Name: count, Length: 104, dtype: int64

# %% [markdown]
# race, marital status, status, survival months, tumor size sütunlarındaki değerlerin sıklık oranlarının grafikleri

# %%
category2=["Age","Grade","Estrogen Status"]
for c in category2:
    print("{} \n".format(train_df[c].value_counts()))
# Out:
# Age
# 47    136
# 46    134
# 49    126
# 53    122
# 57    121
# 50    120
# 61    119
# 51    115
# 59    114
# 55    114
# 62    113
# 48    113
# 56    113
# 63    112
# 60    109
# 54    105
# 64    101
# 65    100
# 67     94
# 58     93
# 52     92
# 68     91
# 66     89
# 69     80
# 45     78
# 43     77
# 42     68
# 44     61
# 41     59
# 40     52
# 39     45
# 38     39
# 37     25
# 36     21
# 35     18
# 32     12
# 33     11
# 34     11
# 31     11
# 30      5
# Name: count, dtype: int64
#
# Grade
# 2                        1867
# 3                         893
# 1                         443
#  anaplastic; Grade IV      16
# Name: count, dtype: int64
#
# Estrogen Status
# Positive    3000
# Negative     219
# Name: count, dtype: int64

# %% [markdown]
# age ve grade sıklık oranları

# %%
def plot_hist(variable):
    plt.figure(figsize=(9,3))
    plt.hist(train_df[variable],bins=50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %%
numericVar=["Age","Race","Marital Status"]
for n in numericVar:
    plot_hist(n)

# %% [markdown]
# age, race, marital status sütunlarının histogram grafikinde gösterimleri

# %% [markdown]
# # Basit Veri Analizi

# %%
train_df["Age"].head()
# Out:
# 2665    61
# 3740    52
# 2138    50
# 1419    66
# 283     50
# Name: Age, dtype: int64

# %% [markdown]
# age sütun değerlerinin indexleriyle beraber yazılması

# %%
train_df["Survival Months"].head()
# Out:
# 2665    69
# 3740    64
# 2138    67
# 1419    83
# 283     92
# Name: Survival Months, dtype: int64

# %% [markdown]
# survival months sütununun ilk 5 değerinin ekrana basılması

# %%
train_df["Tumor Size"].head()
# Out:
# 2665    14
# 3740    34
# 2138    12
# 1419    15
# 283     21
# Name: Tumor Size, dtype: int64

# %% [markdown]
# tumor size sütununun ilk 5 değerinin ekrana basılması

# %%
train_df[["Age","Tumor Size"]].groupby(["Age"],as_index="True").mean().sort_values(by="Tumor Size",ascending=True)
# Out:
#      Tumor Size
# Age
# 66    25.280899
# 67    25.893617
# 62    26.106195
# 51    26.678261
# 34    27.090909
# 53    27.483607
# 55    27.912281
# 65    27.990000
# 68    28.153846
# 32    28.250000
# 61    28.512605
# 42    28.617647
# 54    28.714286
# 57    29.074380
# 46    29.097015
# 41    29.661017
# 59    29.842105
# 43    30.077922
# 45    30.282051
# 48    30.398230
# 33    30.636364
# 35    30.722222
# 36    30.857143
# 64    31.099010
# 69    31.187500
# 50    31.358333
# 52    31.750000
# 60    31.908257
# 37    32.000000
# 63    32.107143
# 56    32.893805
# 49    33.015873
# 40    33.076923
# 44    33.245902
# 47    35.036765
# 58    35.279570
# 39    36.666667
# 38    41.846154
# 31    42.818182
# 30    43.400000

# %% [markdown]
# age ve tumor size birleştirlip aynı yaştaki insanların tümör büyüklüklerinin ortalama değerleri

# %%
train_df[["Race","Tumor Size"]].groupby(["Race"],as_index=False).mean().sort_values(by="Tumor Size",ascending=True)
# Out:
#     Race  Tumor Size
# 0  Black   29.698745
# 2  White   30.291990
# 1  Other   31.309963

# %% [markdown]
# race ve  tumor size birleştirlip aynı ırktaki insanların tümör büyüklüklerinin ortalama değerleri

# %% [markdown]
# # Boş Değerlerin Bulunması

# %%
train_df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 2665   61  White        Widowed       T1      N1       IIA
# 3740   52  White        Married       T2      N1       IIB
# 2138   50  White        Single        T1      N1       IIA
# 1419   66  White       Divorced       T1      N1       IIA
# 283    50  White      Separated       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 1130   63  White        Married       T1      N1       IIA
# 1294   46  White        Married       T1      N1       IIA
# 860    57  White        Single        T2      N1       IIB
# 3507   48  Other        Married       T2      N1       IIB
# 3174   53  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 2665  Moderately differentiated     2  Regional          14        Positive
# 3740        Well differentiated     1  Regional          34        Positive
# ...

# %%
train_df_len=len(train_df)

# %%
train_df_len
# Out:
# 3219

# %% [markdown]
# train dataframe'nin uzunluğunun elde edilmesi ve ekrana basılması

# %%
train_df=pd.concat([train_df,test_df],axis=0).reset_index(drop=True)
train_df.shape
# Out:
# (4024, 17)

# %%
train_df.at[2, 'Age'] = np.nan
train_df.at[713, 'Age'] = np.nan
train_df.at[44, 'Age'] = np.nan
train_df.at[56, 'Age'] = np.nan
train_df.at[960, 'Age'] = np.nan
train_df.at[1453, 'Tumor Size'] = np.nan
train_df.at[563, 'Tumor Size'] = np.nan
train_df.at[287, 'Tumor Size'] = np.nan
train_df.at[333, 'Tumor Size'] = np.nan
train_df.at[830, 'Tumor Size'] = np.nan
train_df.at[125, 'Tumor Size'] = np.nan
train_df.at[899, 'Tumor Size'] = np.nan
train_df.at[70, 'Tumor Size'] = np.nan
train_df.at[670, 'Tumor Size'] = np.nan

# %% [markdown]
# bazı değerleri manuel olarak siliyorum ki boş değerler bulunabilsin

# %%
train_df.columns[train_df.isnull().any()]
# Out:
# Index(['Age', 'Tumor Size'], dtype='object')

# %% [markdown]
# hangi sütunlarda boş değer var

# %%
train_df.isnull().sum()
# Out:
# Age                       5
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                9
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# Name                      0
# dtype: int64

# %% [markdown]
# sütunlardaki boş değer sayıları

# %%
train_df["Age"]
# Out:
# 0       61.0
# 1       52.0
# 2        NaN
# 3       66.0
# 4       50.0
#         ...
# 4019    51.0
# 4020    57.0
# 4021    52.0
# 4022    62.0
# 4023    44.0
# Name: Age, Length: 4024, dtype: float64

# %% [markdown]
# Age sütun bilgisi

# %%
train_df["Grade"]
# Out:
# 0       2
# 1       1
# 2       1
# 3       3
# 4       2
#        ..
# 4019    2
# 4020    2
# 4021    2
# 4022    2
# 4023    3
# Name: Grade, Length: 4024, dtype: object

# %% [markdown]
# grade sütun bilgisi

# %%
train_df.boxplot(column="Age",by="Grade")
plt.show()

# %% [markdown]
# grade sütunun age değerleri üzerindeki dağılımı

# %%
train_df[train_df["Tumor Size"].isnull()]
# Out:
#        Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 70    53.0  White        Married       T2      N1       IIB
# 125   63.0  White        Married       T3      N2      IIIA
# 287   36.0  White        Married       T1      N2      IIIA
# 333   65.0  White       Divorced       T2      N1       IIB
# 563   46.0  White        Married       T1      N1       IIA
# 670   54.0  White      Separated       T4      N3      IIIC
# 830   50.0  White        Single        T1      N1       IIA
# 899   47.0  White        Married       T2      N1       IIB
# 1453  62.0  White        Widowed       T3      N3      IIIC
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 70    Moderately differentiated     2  Regional         NaN        Positive
# 125   Moderately differentiated     2  Regional         NaN        Positive
# 287   Moderately differentiated     2  Regional         NaN        Positive
# ...

# %% [markdown]
# tumor size değei boş olan satırların getirilmesi

# %%
Tumor_mean=train_df["Tumor Size"].mean()
train_df["Tumor Size"]=train_df["Tumor Size"].fillna(Tumor_mean)

# %% [markdown]
# boş değerleri ortalama tumor size değeriyle doldurulması

# %%
train_df[train_df["Tumor Size"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Race, Marital Status, T Stage , N Stage, 6th Stage, differentiate, Grade, A Stage, Tumor Size, Estrogen Status, Progesterone Status, Regional Node Examined, Reginol Node Positive, Survival Months, Status, Name]
# Index: []

# %% [markdown]
# tumor size değei boş olan satırların getirilmesi

# %%
train_df[train_df["Age"].isnull()]
# Out:
#      Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 2    NaN  White        Single        T1      N1       IIA
# 44   NaN  White        Married       T3      N2      IIIA
# 56   NaN  Black        Widowed       T2      N1       IIB
# 713  NaN  White        Married       T2      N1       IIB
# 960  NaN  White        Married       T1      N2      IIIA
#
#                  differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 2          Well differentiated     1  Regional        12.0        Positive
# 44   Moderately differentiated     2  Regional        55.0        Positive
# 56       Poorly differentiated     3  Regional        25.0        Positive
# 713  Moderately differentiated     2  Regional        30.0        Positive
# 960  Moderately differentiated     2  Regional        20.0        Positive
#
#     Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 2              Positive                       9                      2
# ...

# %% [markdown]
# age değei boş olan satırların getirilmesi

# %%
Age_mean=train_df["Age"].mean()
train_df["Age"]=train_df["Age"].fillna(Age_mean)

# %% [markdown]
# boş değerleri ortalama age değeriyle doldurulması

# %%
train_df[train_df["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Race, Marital Status, T Stage , N Stage, 6th Stage, differentiate, Grade, A Stage, Tumor Size, Estrogen Status, Progesterone Status, Regional Node Examined, Reginol Node Positive, Survival Months, Status, Name]
# Index: []

# %% [markdown]
# age değeri boş olan satırların getirilmesi

# %% [markdown]
# # Veri Görselleştirme

# %%
list1=["Age","Regional Node Examined","Reginol Node Positive","Survival Months","Tumor Size"]
sns.heatmap(train_df[list1].corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# elemanların ilişkileri

# %%
g=sns.catplot(x="Status",y="Age", kind="bar",data=train_df)
plt.show()

# %% [markdown]
# status sütunundaki değerlerin age değerine göre dağılımı

# %%
g=sns.catplot(x="Status",y="Tumor Size", kind="bar",data=train_df)
plt.show()

# %% [markdown]
# status sütunundaki değerlerin tumor size değerine göre dağılımı

# %%
g=sns.catplot(x="Status",y="Regional Node Examined", kind="bar",data=train_df)
plt.show()

# %% [markdown]
# status sütunundaki değerlerin reginol node exxamined değerine göre dağılımı

# %%
g=sns.catplot(x="Status",y="Reginol Node Positive", kind="bar",data=train_df)
plt.show()

# %% [markdown]
# status sütunundaki değerlerin reginoal node positive değerine göre dağılımı

# %%
g=sns.catplot(x="Status",y="Survival Months", kind="bar",data=train_df)
plt.show()

# %% [markdown]
# status sütunundaki değerlerin survival months değerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status")
g.map(sns.distplot,"Age",bins=25)
plt.show()

# %% [markdown]
# status değerlerinin age değerlerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status")
g.map(sns.distplot,"Tumor Size",bins=25)
plt.show()

# %% [markdown]
# status değerlerinin tumor size değerlerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status")
g.map(sns.distplot,"Survival Months",bins=25)
plt.show()

# %% [markdown]
# status değerlerinin survival months değerlerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status",row="Race")
g.map(plt.hist,"Age",bins=50)
g.add_legend()
plt.show()

# %% [markdown]
# status değerlerinin race değerlerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status",row="Marital Status")
g.map(plt.hist,"Age",bins=50)
g.add_legend()
plt.show()

# %% [markdown]
# status değerlerinin marital status değerlerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status",row="Estrogen Status")
g.map(plt.hist,"Age",bins=50)
g.add_legend()
plt.show()

# %% [markdown]
# status değerlerinin estrogen status değerlerine göre dağılımı

# %%
g=sns.FacetGrid(train_df,col="Status",row="Progesterone Status")
g.map(plt.hist,"Age",bins=50)
g.add_legend()
plt.show()

# %% [markdown]
# status değerlerinin progesterone status değerlerine göre dağılımı

# %% [markdown]
# # Özellik Mühendisliği

# %%
train_df
# Out:
#             Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0     61.000000  White        Widowed       T1      N1       IIA
# 1     52.000000  White        Married       T2      N1       IIB
# 2     53.971386  White        Single        T1      N1       IIA
# 3     66.000000  White       Divorced       T1      N1       IIA
# 4     50.000000  White      Separated       T2      N1       IIB
# ...         ...    ...            ...      ...     ...       ...
# 4019  51.000000  White        Married       T1      N2      IIIA
# 4020  57.000000  White       Divorced       T2      N1       IIB
# 4021  52.000000  White       Divorced       T2      N2      IIIA
# 4022  62.000000  White        Married       T1      N1       IIA
# 4023  44.000000  Other        Married       T1      N1       IIA
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0     Moderately differentiated     2  Regional        14.0        Positive
# ...

# %%
train_df["Name"].head(10)
# Out:
# 0     Miss. Emily Anderson
# 1         Mrs. Lisa Miller
# 2        Miss. Lisa Miller
# 3       Mrs. Diana Stewart
# 4          Mrs. Lea Wilson
# 5        Miss. Sarah Smith
# 6    Miss. Elizabeth Scott
# 7       Miss. Ayşe Stewart
# 8         Miss. Mary Clark
# 9         Mrs. Ayşe Miller
# Name: Name, dtype: object

# %% [markdown]
# Name sütunundaki ilk 10 değer

# %%
name = train_df["Name"]
name
# Out:
# 0       Miss. Emily Anderson
# 1           Mrs. Lisa Miller
# 2          Miss. Lisa Miller
# 3         Mrs. Diana Stewart
# 4            Mrs. Lea Wilson
#                 ...
# 4019        Mrs. Alice Brown
# 4020       Miss. Emily Scott
# 4021          Mrs. Lisa Reid
# 4022       Miss. Alice Young
# 4023         Mrs. Ayşe Brown
# Name: Name, Length: 4024, dtype: object

# %% [markdown]
# Name sütunundaki değerler

# %%
x= [i.split(".")[0] for i in name]
x
# Out:
# ['Miss',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Mrs',
# ...

# %% [markdown]
# name sütunundaki değerlerin . değerine göre ayrılması

# %%
train_df["Title"]=[i.split(".")[0] for i in name]
title=train_df["Title"].head(10)
title
# Out:
# 0    Miss
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4     Mrs
# 5    Miss
# 6    Miss
# 7    Miss
# 8    Miss
# 9     Mrs
# Name: Title, dtype: object

# %% [markdown]
# yeni title sütunu oluşturulması

# %%
df_cerceve2=pd.DataFrame(title)
df_cerceve2
# Out:
#   Title
# 0  Miss
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4   Mrs
# 5  Miss
# 6  Miss
# 7  Miss
# 8  Miss
# 9   Mrs

# %% [markdown]
# title sütunundan yeni dataframe oluşturulması

# %%
sns.countplot(x="Title",data=df_cerceve2)
plt.show()

# %% [markdown]
# yeni dataframedeki dağılım grafiki

# %%
train_df["Title"]
# Out:
# 0       Miss
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4        Mrs
#         ...
# 4019     Mrs
# 4020    Miss
# 4021     Mrs
# 4022    Miss
# 4023     Mrs
# Name: Title, Length: 4024, dtype: object

# %%
title_mapping={'Miss':0,'Mrs':1}
train_df['Title']=train_df['Title'].map(title_mapping)
train_df['Title'].head(20)
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
# 5     0
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    0
# 13    0
# 14    0
# 15    0
# 16    1
# 17    1
# 18    1
# 19    1
# Name: Title, dtype: int64

# %% [markdown]
# Title sütunundaki değerleri sayısall değerlere çevirme işlemi

# %%
sns.countplot(x="Title",data=train_df)
plt.show()

# %%
g=sns.catplot(x="Title",y="Survival Months",data=train_df,kind="bar")
g.set_xticklabels(["Miss","Mrs"])
g.set_ylabels("Survival Months")
plt.show()

# %%
train_df
# Out:
#             Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0     61.000000  White        Widowed       T1      N1       IIA
# 1     52.000000  White        Married       T2      N1       IIB
# 2     53.971386  White        Single        T1      N1       IIA
# 3     66.000000  White       Divorced       T1      N1       IIA
# 4     50.000000  White      Separated       T2      N1       IIB
# ...         ...    ...            ...      ...     ...       ...
# 4019  51.000000  White        Married       T1      N2      IIIA
# 4020  57.000000  White       Divorced       T2      N1       IIB
# 4021  52.000000  White       Divorced       T2      N2      IIIA
# 4022  62.000000  White        Married       T1      N1       IIA
# 4023  44.000000  Other        Married       T1      N1       IIA
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0     Moderately differentiated     2  Regional        14.0        Positive
# ...

# %%
train_df.drop(labels = ["Name"], axis = 1, inplace = True)

# %% [markdown]
# name sütununun atılması

# %%
train_df.head()
# Out:
#          Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0  61.000000  White        Widowed       T1      N1       IIA
# 1  52.000000  White        Married       T2      N1       IIB
# 2  53.971386  White        Single        T1      N1       IIA
# 3  66.000000  White       Divorced       T1      N1       IIA
# 4  50.000000  White      Separated       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0  Moderately differentiated     2  Regional        14.0        Positive
# 1        Well differentiated     1  Regional        34.0        Positive
# 2        Well differentiated     1  Regional        12.0        Positive
# 3      Poorly differentiated     3  Regional        15.0        Positive
# 4  Moderately differentiated     2  Regional        21.0        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      26                      2
# ...

# %% [markdown]
# train dataframe'in ilk 5 değeri

# %%
train_df = pd.get_dummies(train_df,columns=["Title"])
train_df.head()
# Out:
#          Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0  61.000000  White        Widowed       T1      N1       IIA
# 1  52.000000  White        Married       T2      N1       IIB
# 2  53.971386  White        Single        T1      N1       IIA
# 3  66.000000  White       Divorced       T1      N1       IIA
# 4  50.000000  White      Separated       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0  Moderately differentiated     2  Regional        14.0        Positive
# 1        Well differentiated     1  Regional        34.0        Positive
# 2        Well differentiated     1  Regional        12.0        Positive
# 3      Poorly differentiated     3  Regional        15.0        Positive
# 4  Moderately differentiated     2  Regional        21.0        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      26                      2
# ...

# %% [markdown]
# Title sütununun değerlerine one hot encoding işlemi

# %% [markdown]
# # 6th Stage

# %%
train_df.head()
# Out:
#          Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0  61.000000  White        Widowed       T1      N1       IIA
# 1  52.000000  White        Married       T2      N1       IIB
# 2  53.971386  White        Single        T1      N1       IIA
# 3  66.000000  White       Divorced       T1      N1       IIA
# 4  50.000000  White      Separated       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0  Moderately differentiated     2  Regional        14.0        Positive
# 1        Well differentiated     1  Regional        34.0        Positive
# 2        Well differentiated     1  Regional        12.0        Positive
# 3      Poorly differentiated     3  Regional        15.0        Positive
# 4  Moderately differentiated     2  Regional        21.0        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      26                      2
# ...

# %%
train_df["6th Stage"].head()
# Out:
# 0    IIA
# 1    IIB
# 2    IIA
# 3    IIA
# 4    IIB
# Name: 6th Stage, dtype: object

# %%
sns.countplot(x="6th Stage",data=train_df)
plt.xticks(rotation=60)
plt.show()

# %%
train_df=pd.get_dummies(train_df,columns=["6th Stage"])
train_df.head()
# Out:
#          Age   Race Marital Status T Stage  N Stage  \
# 0  61.000000  White        Widowed       T1      N1
# 1  52.000000  White        Married       T2      N1
# 2  53.971386  White        Single        T1      N1
# 3  66.000000  White       Divorced       T1      N1
# 4  50.000000  White      Separated       T2      N1
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  ...  \
# 0  Moderately differentiated     2  Regional        14.0        Positive  ...
# 1        Well differentiated     1  Regional        34.0        Positive  ...
# 2        Well differentiated     1  Regional        12.0        Positive  ...
# 3      Poorly differentiated     3  Regional        15.0        Positive  ...
# 4  Moderately differentiated     2  Regional        21.0        Positive  ...
#
#   Reginol Node Positive  Survival Months  Status  Title_0 Title_1  \
# 0                     2               69   Alive     True   False
# ...

# %% [markdown]
# 6th stage sütununun değerlerine one hot encoding işleminin uygulanması

# %% [markdown]
# # N Stage

# %%
train_df.head()
# Out:
#          Age   Race Marital Status T Stage  N Stage  \
# 0  61.000000  White        Widowed       T1      N1
# 1  52.000000  White        Married       T2      N1
# 2  53.971386  White        Single        T1      N1
# 3  66.000000  White       Divorced       T1      N1
# 4  50.000000  White      Separated       T2      N1
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  ...  \
# 0  Moderately differentiated     2  Regional        14.0        Positive  ...
# 1        Well differentiated     1  Regional        34.0        Positive  ...
# 2        Well differentiated     1  Regional        12.0        Positive  ...
# 3      Poorly differentiated     3  Regional        15.0        Positive  ...
# 4  Moderately differentiated     2  Regional        21.0        Positive  ...
#
#   Reginol Node Positive  Survival Months  Status  Title_0 Title_1  \
# 0                     2               69   Alive     True   False
# ...

# %%
train_df["N Stage"].head()
# Out:
# 0    N1
# 1    N1
# 2    N1
# 3    N1
# 4    N1
# Name: N Stage, dtype: object

# %%
sns.countplot(x="N Stage",data=train_df)
plt.xticks(rotation=60)
plt.show()

# %%
train_df=pd.get_dummies(train_df,columns=["N Stage"])
train_df.head()
# Out:
#          Age   Race Marital Status T Stage               differentiate Grade  \
# 0  61.000000  White        Widowed       T1  Moderately differentiated     2
# 1  52.000000  White        Married       T2        Well differentiated     1
# 2  53.971386  White        Single        T1        Well differentiated     1
# 3  66.000000  White       Divorced       T1      Poorly differentiated     3
# 4  50.000000  White      Separated       T2  Moderately differentiated     2
#
#     A Stage  Tumor Size Estrogen Status Progesterone Status  ...  Title_0  \
# 0  Regional        14.0        Positive            Positive  ...     True
# 1  Regional        34.0        Positive            Positive  ...    False
# 2  Regional        12.0        Positive            Positive  ...     True
# 3  Regional        15.0        Positive            Positive  ...    False
# 4  Regional        21.0        Positive            Positive  ...    False
#
# ...

# %% [markdown]
# N Stage sütununun değerlerine one hot encoding işleminin uygulanması

# %% [markdown]
# # Estrogen Status

# %%
train_df.head()
# Out:
#          Age   Race Marital Status T Stage               differentiate Grade  \
# 0  61.000000  White        Widowed       T1  Moderately differentiated     2
# 1  52.000000  White        Married       T2        Well differentiated     1
# 2  53.971386  White        Single        T1        Well differentiated     1
# 3  66.000000  White       Divorced       T1      Poorly differentiated     3
# 4  50.000000  White      Separated       T2  Moderately differentiated     2
#
#     A Stage  Tumor Size Estrogen Status Progesterone Status  ...  Title_0  \
# 0  Regional        14.0        Positive            Positive  ...     True
# 1  Regional        34.0        Positive            Positive  ...    False
# 2  Regional        12.0        Positive            Positive  ...     True
# 3  Regional        15.0        Positive            Positive  ...    False
# 4  Regional        21.0        Positive            Positive  ...    False
#
# ...

# %%
train_df["Estrogen Status"].head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: Estrogen Status, dtype: object

# %% [markdown]
# estrogen status sütunnun ilk 5 değeri

# %%
sns.countplot(x="Estrogen Status",data=train_df)
plt.xticks(rotation=60)
plt.show()

# %%
train_df=pd.get_dummies(train_df,columns=["Estrogen Status"])
train_df.head()
# Out:
#          Age   Race Marital Status T Stage               differentiate Grade  \
# 0  61.000000  White        Widowed       T1  Moderately differentiated     2
# 1  52.000000  White        Married       T2        Well differentiated     1
# 2  53.971386  White        Single        T1        Well differentiated     1
# 3  66.000000  White       Divorced       T1      Poorly differentiated     3
# 4  50.000000  White      Separated       T2  Moderately differentiated     2
#
#     A Stage  Tumor Size Progesterone Status  Regional Node Examined  ...  \
# 0  Regional        14.0            Positive                      26  ...
# 1  Regional        34.0            Positive                       2  ...
# 2  Regional        12.0            Positive                       9  ...
# 3  Regional        15.0            Positive                      14  ...
# 4  Regional        21.0            Positive                      12  ...
#
# ...

# %% [markdown]
# Estrogen Status sütununun değerlerine one hot encoding işleminin uygulanması
